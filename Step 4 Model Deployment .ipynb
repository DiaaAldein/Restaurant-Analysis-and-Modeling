# %% [markdown]
# # Creating Python file app.py for model deployment on streamlit

# %%
import pandas as pd
import joblib

# %%
features = joblib.load('../models/features.pkl')
features
# Out:
# ['online_order',
#  'book_table',
#  'location',
#  'rest_type',
#  'cuisines',
#  'approx_cost_for_two_people',
#  'listed_in_type',
#  'listed_in_city']

# %%
# %%writefile ../models/app.py

import streamlit as st
import pandas as pd
import joblib
import sklearn
import category_encoders

model = joblib.load('../models/rf_model.pkl')
features = joblib.load('../models/features.pkl')
dummies = joblib.load('../models/dummies_dict.pkl')

def prediction(online_order,book_table,location,rest_type,cuisines,approx_cost_for_two_people,listed_in_type,listed_in_city):
    df = pd.DataFrame(columns=features)
    df.at[0,'online_order'] = online_order
    df.at[0,'book_table'] = book_table
    df.at[0,'location'] = location
    df.at[0,'rest_type'] = rest_type
    df.at[0,'cuisines'] = cuisines
    df.at[0,'approx_cost_for_two_people'] = approx_cost_for_two_people
    df.at[0,'listed_in_type'] = listed_in_type
    df.at[0,'listed_in_city'] = listed_in_city
    result = model.predict(df)
    return result[0]

def main():
    st.title("Bangalore New Restaurants expectation if it is going to be good or not")
    online_order = st.selectbox("Online order (if avilable selct 1, if not 0)",[0,1])
    book_table = st.selectbox("book table (if avilable selct 1, if not 0)",[0,1])
    location = st.selectbox("Select Location", dummies['location'])
    rest_type = st.selectbox("Select rest_type", dummies['rest_type'])
    cuisines = st.selectbox("Select cuisines", dummies['cuisines'])
    approx_cost_for_two_people = st.slider("Select approx_cost_for_two_people", min_value = 0 , max_value =7000, value = 500, step=1)
    listed_in_type = st.selectbox("Select listed_in_type", dummies['listed_in_type'])
    listed_in_city = st.selectbox("Select listed_in_city", dummies['listed_in_city'])
    
    if st.button("Predict"):
        result = prediction(online_order,book_table,location,rest_type,cuisines,approx_cost_for_two_people,listed_in_type,listed_in_city)
        result_list = ["Baad Your Restaurant may not success ","Good Your Restaurant will success "]
        st.text(result_list[result])
        
        
main()
# Out:
# Overwriting ../models/app.py

# %%
dummies = joblib.load('../models/dummies_dict.pkl')
dummies
# Out:
# {'location': ['Banashankari',
#   'Basavanagudi',
#   'Mysore Road',
#   'Jayanagar',
#   'Kumaraswamy Layout',
#   'Rajarajeshwari Nagar',
#   'Vijay Nagar',
#   'Uttarahalli',
#   'JP Nagar',
#   'South Bangalore',
#   'City Market',
#   'Bannerghatta Road',
#   'BTM',
#   'Kanakapura Road',
#   'Bommanahalli',
#   'Electronic City',
#   'Wilson Garden',
#   'Shanti Nagar',
#   'Koramangala 5th Block',
#   'Richmond Road',
#   'HSR',
#   'Koramangala 7th Block',
#   'Bellandur',
#   'Sarjapur Road',
#   'Marathahalli',
#   'Whitefield',
#   'East Bangalore',
#   'Old Airport Road',
#   'Indiranagar',
#   'Koramangala 1st Block',
#   'Frazer Town',
#   'MG Road',
#   'Brigade Road',
#   'Lavelle Road',
#   'Church Street',
#   'Ulsoor',
#   'Residency Road',
#   'Shivajinagar',
#   'Infantry Road',
#   'St. Marks Road',
#   'Cunningham Road',
#   'Race Course Road',
#   'Commercial Street',
#   'Vasanth Nagar',
#   'Domlur',
#   'Koramangala 8th Block',
#   'Ejipura',
#   'Jeevan Bhima Nagar',
#   'Old Madras Road',
#   'Seshadripuram',
#   'Kammanahalli',
#   'Koramangala 6th Block',
#   'Majestic',
#   'Langford Town',
#   'Central Bangalore',
#   'Brookefield',
#   'ITPL Main Road, Whitefield',
#   'Varthur Main Road, Whitefield',
#   'Koramangala 2nd Block',
#   'Koramangala 3rd Block',
#   'Koramangala 4th Block',
#   'Koramangala',
#   'Hosur Road',
#   'RT Nagar',
#   'Banaswadi',
#   'North Bangalore',
#   'Nagawara',
#   'Hennur',
#   'Kalyan Nagar',
#   'HBR Layout',
#   'Rammurthy Nagar',
#   'Thippasandra',
#   'CV Raman Nagar',
#   'Kaggadasapura',
#   'Kengeri',
#   'Sankey Road',
#   'Malleshwaram',
#   'Sanjay Nagar',
#   'Sadashiv Nagar',
#   'Basaveshwara Nagar',
#   'Rajajinagar',
#   'Yeshwantpur',
#   'New BEL Road',
#   'West Bangalore',
#   'Magadi Road',
#   'Yelahanka',
#   'Sahakara Nagar',
#   'Jalahalli',
#   'Hebbal',
#   'Nagarbhavi',
#   'Peenya',
#   'KR Puram'],
#  'rest_type': ['Casual Dining',
#   'Cafe, Casual Dining',
#   'Quick Bites',
#   'Cafe',
#   'Cafe, Quick Bites',
#   'Delivery',
#   'Mess',
#   'Dessert Parlor',
#   'Bakery, Dessert Parlor',
#   'Pub',
#   'Bakery',
#   'Delivery, Takeaway',
#   'Fine Dining',
#   'Beverage Shop',
#   'Sweet Shop',
#   'Bar',
#   'Dessert Parlor, Sweet Shop',
#   'Bakery, Quick Bites',
#   'Quick Bites, Sweet Shop',
#   'Kiosk',
#   'Food Truck',
#   'Dessert Parlor, Quick Bites',
#   'Beverage Shop, Quick Bites',
#   'Beverage Shop, Dessert Parlor',
#   'Takeaway',
#   'Casual Dining, Pub',
#   'Bar, Casual Dining',
#   'Casual Dining, Microbrewery',
#   'Lounge',
#   'Food Court',
#   'Bakery, Cafe',
#   'Dhaba',
#   'Microbrewery',
#   'Food Court, Quick Bites',
#   'Bar, Pub',
#   'Bar, Lounge',
#   'Dessert Parlor, Food Court',
#   'Casual Dining, Sweet Shop',
#   'Casual Dining, Food Court',
#   'Casual Dining, Lounge',
#   'Cafe, Food Court',
#   'Beverage Shop, Cafe',
#   'Cafe, Dessert Parlor',
#   'Microbrewery, Pub',
#   'Bakery, Food Court',
#   'Club',
#   'Cafe, Pub',
#   'Casual Dining, Irani Cafee',
#   'Fine Dining, Lounge',
#   'Bar, Quick Bites',
#   'Confectionery',
#   'Lounge, Microbrewery',
#   'Fine Dining, Microbrewery',
#   'Bar, Fine Dining',
#   'Dessert Parlor, Kiosk',
#   'Bhojanalya',
#   'Casual Dining, Quick Bites',
#   'Bar, Cafe',
#   'Bakery, Beverage Shop',
#   'Bar, Microbrewery',
#   'Cafe, Lounge',
#   'Casual Dining, Club',
#   'Mess, Quick Bites',
#   'Meat Shop, Quick Bites',
#   'Kiosk, Quick Bites',
#   'Beverage Shop, Food Court'],
#  'cuisines': ['Chinese, Mughlai, North Indian',
#   'Chinese, North Indian, Thai',
#   'Cafe, Italian, Mexican',
#   'North Indian, South Indian',
#   'North Indian, Rajasthani',
#   'North Indian',
#   'Andhra, Chinese, North Indian, South Indian',
#   'Cafe, Italian, Pizza',
#   'Cafe, Continental, Italian',
#   'Beverages, Cafe, Italian, Mexican, Momos',
#   'Cafe',
#   'Cafe, Chinese, Continental, Italian',
#   'Cafe, Continental',
#   'Cafe, Chinese, Continental, Fast Food, Momos',
#   'Cafe, Chinese, Italian',
#   'American, Cafe, Italian',
#   'Cafe, French, North Indian',
#   'Beverages, Cafe, Fast Food, Pizza',
#   'Cafe, Fast Food',
#   'Cafe, European, Fast Food, Italian',
#   'Bakery, Cafe',
#   'Cafe, South Indian',
#   'Beverages, Cafe, Fast Food',
#   'Cafe, Chinese, Fast Food, North Indian',
#   'Cafe, Italian',
#   'Burger, Chinese, Fast Food, North Indian',
#   'Bakery, Desserts',
#   'Pizza',
#   'Biryani, Fast Food, North Indian',
#   'Biryani',
#   'Chinese, Fast Food, North Indian',
#   'Chinese, Momos, Thai',
#   'Chinese, Mughlai, North Indian, South Indian',
#   'South Indian',
#   'Fast Food, Street Food',
#   'Burger, Fast Food',
#   'Fast Food, Pizza',
#   'Continental, Italian, North Indian',
#   'Chinese, North Indian',
#   'Biryani, Chinese, North Indian, Rolls',
#   'Chinese, Thai',
#   'Chinese, Momos, North Indian, Rolls',
#   'Beverages, Fast Food, Street Food',
#   'Desserts, Ice Cream',
#   'Andhra, Biryani, Chinese, North Indian, South Indian',
#   'Chinese, Continental, Fast Food, Italian, Momos',
#   'American, Biryani, Burger, Chinese, Continental, Healthy Food, North Indian, Salad',
#   'Biryani, Fast Food',
#   'Asian, Chinese, Indonesian, Japanese, Korean, Momos, Thai',
#   'Beverages, Desserts',
#   'Italian, Mexican, North Indian',
#   'Biryani, Chinese, Goan, North Indian, Seafood',
#   'Chinese',
#   'Bakery',
#   'Chinese, Fast Food, Kebab, North Indian',
#   'Chinese, Continental, Italian, Mexican, North Indian, Steak',
#   'Beverages, Burger, Fast Food',
#   'Biryani, Italian, North Indian',
#   'Biryani, Chinese, Kebab',
#   'Chinese, Continental, Italian, North Indian',
#   'Fast Food, Momos, Rolls',
#   'Biryani, South Indian',
#   'Fast Food',
#   'Chinese, North Indian, South Indian',
#   'Andhra, Biryani, Chinese, Kebab, North Indian, Seafood',
#   'Beverages, Desserts, Ice Cream',
#   'Mithai, Street Food',
#   'Biryani, Chinese, North Indian',
#   'Desserts',
#   'Ice Cream',
#   'Bakery, Fast Food',
#   'Iranian, North Indian',
#   'Beverages, Desserts, Ice Cream, Sandwich',
#   'Biryani, Chinese, Fast Food, North Indian',
#   'Chinese, North Indian, South Indian, Street Food',
#   'Mangalorean, North Indian, South Indian',
#   'Fast Food, South Indian',
#   'Beverages, Chinese, North Indian, South Indian',
#   'Chinese, Juices, North Indian, South Indian',
#   'Biryani, Chinese, Kebab, North Indian',
#   'Chinese, Mughlai, North Indian, Rolls',
#   'Fast Food, Mughlai, North Indian',
#   'Beverages, Desserts, Fast Food, Ice Cream, Sandwich',
#   'Beverages, Biryani, Chinese, North Indian',
#   'Beverages, Ice Cream, Juices',
#   'Biryani, Chinese, Seafood',
#   'Desserts, Mithai',
#   'Beverages, Cafe',
#   'Chinese, South Indian',
#   'Asian, Chinese, Thai, Vietnamese',
#   'Beverages, Ice Cream',
#   'Italian, Pizza',
#   'Fast Food, North Indian, Rolls',
#   'Burger, Desserts, Healthy Food, Juices, Pizza, Salad, Sandwich',
#   'Street Food',
#   'Andhra, Biryani, Hyderabadi, North Indian',
#   'Burger, Cafe, Continental, Desserts, Italian',
#   'Beverages, Sandwich',
#   'Italian',
#   'Beverages, Fast Food, Italian',
#   'Bengali, Chinese, Sandwich',
#   'Biryani, Chinese, North Indian, South Indian',
#   'Juices, North Indian, Street Food',
#   'Arabian',
#   'Beverages, Chinese, North Indian',
#   'Arabian, BBQ, Chinese, Desserts, Juices, Kebab, North Indian, Rolls',
#   'Biryani, Chinese, Mangalorean, Seafood',
#   'Continental, Fast Food, Momos, Street Food',
#   'Burger, Fast Food, Pizza, Sandwich',
#   'BBQ, Chinese, North Indian',
#   'Chinese, Fast Food',
#   'Chinese, Continental, North Indian',
#   'Vietnamese',
#   'Italian, Salad',
#   'Andhra, Chinese, North Indian, Seafood',
#   'Mangalorean, Seafood, South Indian',
#   'Andhra',
#   'Arabian, Chinese, Mangalorean, North Indian, Seafood, South Indian',
#   'Beverages, Tea',
#   'North Indian, Street Food',
#   'Beverages, Burger, Cafe',
#   'Mangalorean, South Indian',
#   'Chinese, Fast Food, Juices, North Indian, South Indian',
#   'Andhra, Biryani, North Indian, South Indian',
#   'Andhra, Biryani, Chinese, Mangalorean, North Indian',
#   'Beverages, Juices',
#   'Fast Food, Salad',
#   'Desserts, Juices',
#   'Biryani, Chinese, North Indian, Seafood, South Indian',
#   'Beverages, South Indian',
#   'Fast Food, Rolls',
#   'Chinese, Fast Food, North Indian, South Indian',
#   'Chinese, North Indian, Rolls',
#   'Beverages, Fast Food',
#   'Andhra, Biryani, North Indian, Seafood',
#   'Chinese, Juices, South Indian, Street Food',
#   'Afghani, Mughlai, North Indian',
#   'Chinese, Italian, Street Food',
#   'Healthy Food, South Indian',
#   'American, Cafe, Pizza',
#   'North Indian, South Indian, Street Food',
#   'Beverages, Biryani, North Indian, South Indian',
#   'South Indian, Street Food',
#   'Beverages, Biryani, Kebab, North Indian, Seafood, South Indian',
#   'Fast Food, North Indian',
#   'Beverages, Cafe, Continental, Desserts',
#   'Biryani, Chinese, Kebab, North Indian, Rolls',
#   'Italian, Pizza, Salad',
#   'Chinese, Fast Food, Rolls',
#   'Italian, Mexican',
#   'Fast Food, Juices',
#   'Chinese, South Indian, Street Food',
#   'Desserts, Fast Food, Ice Cream',
#   'Cafe, Chinese, Fast Food',
#   'Desserts, Momos',
#   'Cafe, Continental, Fast Food',
#   'Chinese, North Indian, Seafood',
#   'Chinese, Continental, North Indian, Thai',
#   'Fast Food, Mithai, South Indian, Street Food',
#   'Desserts, North Indian, South Indian',
#   'Burger, South Indian',
#   'Mangalorean, North Indian, Seafood',
#   'BBQ, Fast Food, Pizza',
#   'Mangalorean, Seafood',
#   'Andhra, Chinese, North Indian',
#   'Beverages, Fast Food, Ice Cream',
#   'Beverages, Desserts, Fast Food',
#   'Chinese, Italian, North Indian, Pizza',
#   'Lebanese, Rolls',
#   'Beverages',
#   'Continental, Finger Food, Pizza, Seafood',
#   'Beverages, Fast Food, Juices',
#   'Chinese, Ice Cream, Street Food',
#   'Fast Food, Rolls, Sandwich',
#   'Rolls',
#   'Mithai',
#   'Continental, Desserts, Fast Food',
#   'BBQ, Fast Food, Italian, Salad',
#   'Italian, North Indian, Pizza, Salad',
#   'Beverages, Continental, Fast Food, Healthy Food, Salad',
#   'Fast Food, Juices, North Indian, South Indian',
#   'Beverages, Cafe, Italian',
#   'Continental, North Indian',
#   'Momos, Tibetan',
#   'Bakery, Desserts, French',
#   'Juices',
#   'Chinese, Fast Food, Juices, South Indian',
#   'Beverages, Fast Food, Tea',
#   'Fast Food, Momos',
#   'Biryani, Chinese, North Indian, Seafood',
#   'Bakery, Chinese, South Indian',
#   'Chinese, Momos, Tibetan',
#   'Healthy Food, North Indian, Thai',
#   'Fast Food, Sandwich',
#   'Arabian, Bakery, Charcoal Chicken, Chinese, Desserts, North Indian, Rolls',
#   'Biryani, Chinese, Continental, South Indian',
#   'Continental, Desserts, Italian, Pizza',
#   'Burger, Fast Food, Pizza',
#   'Biryani, Chinese',
#   'Andhra, Biryani, Chinese, North Indian',
#   'American, Asian, Continental, Finger Food, North Indian',
#   'Biryani, North Indian',
#   'Beverages, Cafe, Continental',
#   'Beverages, Chinese, North Indian, South Indian, Street Food',
#   'Chinese, Juices, North Indian, Rolls, South Indian, Street Food',
#   'Beverages, Desserts, Italian, Juices',
#   'Chinese, Mithai, North Indian, Street Food',
#   'Bakery, Street Food',
#   'Finger Food',
#   'Chinese, Momos, Thai, Vietnamese',
#   'Chinese, Mangalorean',
#   'Continental',
#   'Juices, Street Food',
#   'Rolls, Street Food',
#   'Kebab',
#   'Continental, Italian',
#   'Beverages, Chinese, Desserts, South Indian',
#   'Fast Food, South Indian, Street Food',
#   'Desserts, Fast Food, North Indian, South Indian',
#   'Mughlai, North Indian',
#   'Biryani, Chinese, Momos, Rolls',
#   'Italian, North Indian',
#   'Arabian, Biryani, Chinese, Fast Food, Middle Eastern, Mughlai, North Indian, Seafood',
#   'Chinese, Continental, North Indian, South Indian',
#   'BBQ, European, Kebab, Mediterranean, North Indian',
#   'Arabian, BBQ, Chinese, Desserts, North Indian',
#   'Chinese, Mughlai, North Indian, Seafood, Thai',
#   'Cafe, Chinese, Continental, Fast Food',
#   'Bakery, Beverages, Cafe',
#   'Beverages, Cafe, Desserts, Fast Food',
#   'Asian, Biryani, Cafe, Healthy Food, Italian, Juices, North Indian',
#   'Cafe, Desserts',
#   'Beverages, Cafe, Desserts',
#   'Cafe, Chinese, Continental, North Indian',
#   'Cafe, Chinese, Fast Food, Finger Food, Street Food',
#   'Bakery, Cafe, Continental, Desserts, North Indian',
#   'Cafe, Desserts, Fast Food',
#   'Burger, Cafe, Sandwich',
#   'Cafe, Continental, North Indian',
#   'Beverages, Cafe, Desserts, North Indian, Sandwich',
#   'Burger, Cafe, Desserts, Italian, Sandwich',
#   'American, Burger, Cafe, Fast Food, Sandwich',
#   'Beverages, Burger, Cafe, Continental, Italian, Rolls',
#   'Cafe, North Indian',
#   'Cafe, Desserts, Italian',
#   'Cafe, Healthy Food',
#   'Biryani, Continental, Desserts, Healthy Food, North Indian, Sandwich',
#   'Andhra, Biryani, North Indian',
#   'North Indian, Rolls, Seafood, South Indian',
#   'Bengali, Chinese',
#   'Bengali, North Indian',
#   'Arabian, Middle Eastern',
#   'Beverages, Charcoal Chicken, Chinese, Kerala, North Indian, Seafood, South Indian',
#   'Charcoal Chicken, North Indian',
#   'Biryani, Charcoal Chicken, Chinese, North Indian, Rolls, Seafood',
#   'Beverages, Italian, Pizza',
#   'Andhra, Biryani, Chinese, Kerala, Mughlai, North Indian, South Indian, Street Food',
#   'Chinese, Momos',
#   'Fast Food, Oriya',
#   'Beverages, Cafe, Fast Food, North Indian',
#   'Andhra, Biryani',
#   'Bihari, North Indian',
#   'Burger, Fast Food, Finger Food, Roast Chicken',
#   'Andhra, Biryani, Chinese',
#   'Kerala, South Indian',
#   'Bohri',
#   'Biryani, Chinese, Fast Food',
#   'Biryani, Mughlai, North Indian',
#   'Biryani, Kebab, North Indian',
#   'Beverages, Fast Food, Kebab, North Indian',
#   'Andhra, North Indian',
#   'Arabian, Fast Food',
#   'Biryani, Chinese, Momos, North Indian',
#   'Biryani, Kebab',
#   'Bengali',
#   'Biryani, Chinese, Fast Food, Kebab, Mughlai',
#   'BBQ, Biryani, Seafood',
#   'Fast Food, North Indian, South Indian',
#   'Chinese, Hyderabadi, North Indian',
#   'African, Burger',
#   'BBQ, Cafe, Chinese, Continental, Lebanese, Middle Eastern, North Indian',
#   'Arabian, Beverages, Biryani, Chinese, North Indian, Rolls, Seafood',
#   'Chinese, North Indian, Street Food',
#   'Chinese, Fast Food, Juices, North Indian, Rolls',
#   'American, Chinese, Continental, North Indian',
#   'BBQ, Biryani, Kebab, North Indian',
#   'Biryani, Kebab, Mughlai, North Indian',
#   'Arabian, Chinese, Juices, Kerala, North Indian, Seafood, South Indian',
#   'Charcoal Chicken, Kebab, Rolls',
#   'Burger',
#   'BBQ, Chinese, Fast Food, North Indian',
#   'Biryani, Kebab, South Indian',
#   'Bengali, Mughlai',
#   'Biryani, North Indian, South Indian',
#   'Chinese, Continental, Fast Food, Healthy Food',
#   'Chinese, Fast Food, Mughlai, North Indian, Rolls',
#   'Bakery, Beverages, Desserts, Ice Cream',
#   'Desserts, Fast Food, Rolls, Street Food',
#   'American, Fast Food, Mexican',
#   'Chinese, Momos, North Indian',
#   'Bengali, Fast Food',
#   'Bengali, Chinese, North Indian',
#   'Andhra, South Indian',
#   'Rajasthani',
#   'Asian, Beverages, Chinese, Fast Food, Nepalese, Tibetan',
#   'Healthy Food',
#   'Asian, Continental, Finger Food',
#   'Chinese, Fast Food, Momos, Street Food, Tibetan',
#   'Mithai, North Indian, Street Food',
#   'Continental, Italian, North Indian, Pizza',
#   'Kerala, North Indian',
#   'Chinese, Rolls',
#   'American, Continental',
#   'Burger, Continental, Italian, Pizza, Salad, Sandwich',
#   'Sandwich, Street Food',
#   'Bakery, Desserts, Fast Food',
#   'Mangalorean',
#   'Biryani, Chinese, Mangalorean, North Indian, Seafood',
#   'Andhra, Biryani, South Indian',
#   'American, Burger, Fast Food',
#   'Biryani, Mughlai, North Indian, Rolls',
#   'Bakery, Beverages, Desserts',
#   'Asian, Burger, Cafe, Continental, Italian, Salad',
#   'Chinese, Momos, North Indian, Seafood, Thai',
#   'American, Sandwich',
#   'Kerala, North Indian, South Indian',
#   'Biryani, Chinese, Hyderabadi, North Indian',
#   'Burger, Finger Food, Sandwich',
#   'Chinese, Mangalorean, North Indian, Seafood',
#   'Continental, North Indian, South Indian',
#   'Hyderabadi, North Indian',
#   'Maharashtrian, Seafood',
#   'Chinese, Continental, Finger Food, North Indian',
#   'Fast Food, Tamil',
#   'Bengali, Chinese, Rolls',
#   'Mexican, Tex-Mex',
#   'Belgian, Beverages, Desserts',
#   'American, Continental, Italian',
#   'Healthy Food, Juices',
#   'Beverages, Gujarati, Street Food',
#   'BBQ, North Indian',
#   'Beverages, North Indian, Street Food',
#   'Beverages, Healthy Food, Juices',
#   'Asian, Continental, European',
#   'Desserts, Fast Food, Mithai',
#   'Juices, South Indian, Street Food',
#   'Biryani, Kerala, South Indian',
#   'Arabian, BBQ, Mughlai',
#   'Chinese, Continental, Finger Food',
#   'Burger, Roast Chicken',
#   'Cafe, Chinese, Italian, Mexican',
#   'Biryani, Chinese, Mexican, North Indian, South Indian',
#   'Juices, Rolls',
#   'Fast Food, Italian, Pizza',
#   'BBQ',
#   'American, Cafe, Chinese, Continental, Italian',
#   'Burger, Cafe, Chinese, Fast Food, North Indian',
#   'Fast Food, Mexican',
#   'Chinese, Kebab, North Indian',
#   'Beverages, Continental, Italian',
#   'Bakery, Desserts, Ice Cream',
#   'Beverages, Fast Food, Momos, North Indian',
#   'BBQ, Chinese, Continental, Italian, Steak, Thai',
#   'Burger, Fast Food, Sandwich',
#   'Arabian, Chinese, Juices, Kerala, North Indian',
#   'Arabian, Fast Food, North Indian',
#   'Chinese, North Indian, Seafood, South Indian',
#   'Asian, Cafe, Continental',
#   'Seafood',
#   'Kerala',
#   'Fast Food, Tea',
#   'Chinese, Italian, Japanese',
#   'Beverages, Cafe, Chinese, Italian',
#   'Beverages, Fast Food, Sandwich',
#   'Gujarati',
#   'Burger, Desserts, Fast Food, Sandwich',
#   'Continental, Italian, South American',
#   'Bengali, North Indian, Oriya',
#   'Biryani, Kebab, Rolls',
#   'Beverages, Chinese, Fast Food',
#   'Desserts, Fast Food',
#   'Chinese, Fast Food, Momos, North Indian',
#   'Fast Food, Kebab, Rolls',
#   'Andhra, North Indian, South Indian',
#   'Fast Food, Healthy Food',
#   'Maharashtrian',
#   'Chinese, Juices, North Indian, South Indian, Street Food',
#   'American, Burger, Italian, Steak',
#   'Healthy Food, North Indian',
#   'Bakery, Desserts, Sandwich',
#   'Desserts, Ice Cream, Juices',
#   'Biryani, Chinese, North Indian, Salad, Seafood',
#   'Beverages, Pizza',
#   'Chinese, Momos, North Indian, Tibetan',
#   'Beverages, Rolls, Seafood, South Indian',
#   'Konkan, Mangalorean, North Indian, Seafood',
#   'Biryani, Desserts, Kerala, Seafood',
#   'Fast Food, Juices, Street Food',
#   'Chinese, Continental, North Indian, Pizza',
#   'Biryani, Chinese, South Indian',
#   'Bakery, Fast Food, Italian',
#   'Biryani, Charcoal Chicken, Chinese, Seafood',
#   'Healthy Food, Salad',
#   'Chinese, Kerala, North Indian',
#   'Fast Food, North Indian, Street Food',
#   'Biryani, Kebab, Mughlai',
#   'Continental, Finger Food',
#   'Arabian, North Indian',
#   'Healthy Food, Pizza, South Indian',
#   'Beverages, Healthy Food',
#   'Chinese, Kerala, South Indian',
#   'American, Cafe, Continental, Italian',
#   'Beverages, Cafe, Continental, Italian, Pizza',
#   'Desserts, Ice Cream, Rolls',
#   'Ice Cream, Juices',
#   'Chinese, Mithai, North Indian, South Indian',
#   'Desserts, Italian, Pizza',
#   'Chinese, Italian, North Indian, South Indian',
#   'Beverages, Street Food',
#   'Continental, North Indian, Street Food',
#   'North Indian, Pizza, South Indian',
#   'Arabian, Mediterranean, North Indian',
#   'Asian, Chinese',
#   'Andhra, Hyderabadi, North Indian',
#   'Asian, Chinese, North Indian, Seafood',
#   'Continental, European',
#   'Chinese, Finger Food, North Indian',
#   'Chinese, Juices, Kebab, North Indian',
#   'Chinese, Mangalorean, North Indian',
#   'Chettinad, Kerala, Seafood, South Indian',
#   'Asian, Continental, North Indian',
#   'Afghani, North Indian',
#   'Cafe, Continental, Desserts, Italian, Mediterranean',
#   'Beverages, Cafe, Healthy Food',
#   'Beverages, Cafe, Continental, Desserts, Healthy Food, Pizza, Salad, Sandwich',
#   'Beverages, Cafe, Salad, Wraps',
#   'Beverages, Cafe, Continental, Sandwich',
#   'Beverages, Cafe, Chinese, Coffee, Fast Food, Momos, North Indian, South Indian',
#   'Burger, Cafe, Fast Food, Pizza',
#   'Cafe, Street Food',
#   'Arabian, Burger, Desserts, Fast Food, Healthy Food, Salad, Turkish',
#   'Beverages, North Indian',
#   'Coffee, South Indian',
#   'Biryani, North Indian, Rolls',
#   'Beverages, Burger, Continental, Desserts, Healthy Food, Juices, Salad',
#   'Chinese, Tibetan',
#   'Chinese, Continental, Mexican, North Indian',
#   'Beverages, Burger, Sandwich',
#   'Gujarati, North Indian, South Indian',
#   'Bakery, Beverages, Desserts, Fast Food',
#   'Biryani, Chinese, Juices, Kerala, Seafood',
#   'Arabian, BBQ, North Indian, Rolls',
#   'Burger, Chinese, Continental, Pizza',
#   'Bakery, Chinese, Continental, Desserts',
#   'Arabian, Chinese, North Indian',
#   'Andhra, Biryani, Chinese, Mangalorean, North Indian, Seafood',
#   'Tea',
#   'Burger, Cafe, Continental',
#   'Biryani, Mughlai',
#   'BBQ, Chinese, North Indian, Pizza',
#   'Burger, Cafe, Continental, Italian',
#   'Biryani, Chinese, Kebab, North Indian, Seafood, South Indian',
#   'Pizza, Salad',
#   'Fast Food, Maharashtrian, Sandwich, Street Food',
#   'Maharashtrian, Street Food',
#   'Biryani, Chinese, North Indian, Rajasthani',
#   'Asian, Continental',
#   'Burger, Fast Food, Italian',
#   'Chinese, Fast Food, Tibetan',
#   'Andhra, Chinese, South Indian',
#   'Chinese, Kebab, Mughlai, North Indian, Rolls',
#   'Konkan, Seafood',
#   'Mithai, South Indian',
#   'Arabian, Chinese, Kerala, North Indian',
#   'Chinese, Kebab, North Indian, South Indian',
#   'Bakery, Healthy Food',
#   'Chinese, Kebab, North Indian, Rolls',
#   'Chinese, Desserts, Juices, North Indian, South Indian',
#   'Sandwich',
#   'Asian, Beverages, Desserts',
#   'Fast Food, Healthy Food, Salad, Sandwich',
#   'Beverages, Ice Cream, Pizza',
#   'Biryani, Seafood, South Indian',
#   'Afghan, Mughlai, North Indian',
#   'Chinese, Italian, Pizza, Thai',
#   'Asian, Chinese, Continental, Italian',
#   'Asian, Biryani, Chinese, Continental, Desserts, Italian, Modern Indian, North Indian',
#   'Asian, Continental, Goan, North Indian, Seafood',
#   'Asian, Momos, North Indian, South Indian',
#   'Iranian, Mediterranean, Mughlai, North Indian',
#   'Mediterranean, Mughlai, North Indian',
#   'Chinese, Fast Food, North Indian, Salad',
#   'Asian, Chinese, Italian, North Indian',
#   'Chinese, Italian, North Indian',
#   'Finger Food, North Indian',
#   'BBQ, European, Mediterranean, North Indian',
#   'Italian, Mughlai, North Indian',
#   'Asian, Chinese, Continental, North Indian, South Indian',
#   'Andhra, Bengali, Chettinad, Continental, North Indian',
#   'Asian, Continental, European, Goan, North Indian',
#   'Bengali, Gujarati, Lucknowi, Maharashtrian, North Indian, South Indian',
#   'American, Chinese, Continental, Finger Food, North Indian, Thai, Vietnamese',
#   'Andhra, Cafe, North Indian, South Indian',
#   'Cafe, Healthy Food, Salad',
#   'Bakery, Cafe, Italian',
#   'Bakery, Burger, Cafe, Fast Food, Pizza',
#   'Cafe, Fast Food, Tea',
#   'Cafe, Continental, Tea',
#   'Cafe, Desserts, Ice Cream',
#   'Beverages, Cafe, European, Italian',
#   'Burger, Cafe, Italian, Salad',
#   'Beverages, Burger, Cafe, Desserts, Ice Cream, Pizza',
#   'Beverages, Cafe, Chinese, Continental, North Indian',
#   'Cafe, Fast Food, Rolls',
#   'Beverages, Burger, Cafe, Fast Food, Pizza',
#   'Biryani, Kerala, Seafood, South Indian',
#   'Beverages, Healthy Food, North Indian',
#   'Chinese, North Indian, Oriya',
#   'Beverages, Fast Food, Ice Cream, Juices, Sandwich',
#   'Chinese, Fast Food, Mithai, North Indian, Street Food',
#   'Arabian, BBQ, Chinese, Kerala, North Indian',
#   'Andhra, Biryani, Chinese, South Indian',
#   'Arabian, Biryani, Chinese, North Indian, Seafood',
#   'Biryani, Rolls',
#   'BBQ, Continental, North Indian',
#   'Biryani, Kebab, Mughlai, Rolls',
#   'Andhra, Biryani, Chinese, Hyderabadi, North Indian, South Indian',
#   'Arabian, Biryani, Chinese, Kebab, Kerala, North Indian, Seafood, South Indian',
#   'Biryani, Chinese, Mughlai, North Indian',
#   'Chinese, Juices, North Indian',
#   'American, Bakery, Beverages, Desserts, Italian, Rolls, Salad, Sandwich',
#   'Arabian, Biryani, Chinese, Kerala, North Indian, Seafood',
#   'American, Chinese, Finger Food, North Indian',
#   'Andhra, Chinese, Hyderabadi, North Indian',
#   'Beverages, Continental, North Indian',
#   'Bakery, Desserts, Italian',
#   'Andhra, Chinese, Hyderabadi, North Indian, South Indian',
#   'Continental, Finger Food, Italian, North Indian, South Indian',
#   'American, BBQ, Burger, Tex-Mex',
#   'Biryani, Hyderabadi, North Indian',
#   'Continental, Fast Food',
#   'Gujarati, Street Food',
#   'Chinese, North Indian, South Indian, Tamil',
#   'Asian, Chinese, Momos',
#   'Continental, Finger Food, Seafood',
#   'Bengali, Oriya',
#   'Beverages, Fast Food, Sandwich, Tea',
#   'Biryani, Chinese, Kebab, Mughlai, North Indian',
#   'Japanese, North Indian',
#   'Fast Food, Mithai',
#   'Italian, Japanese, Korean, Mexican, North Indian, Thai',
#   'Chinese, Continental, Italian, Steak',
#   'Turkish',
#   'Modern Indian',
#   'Continental, Italian, Mexican, Pizza',
#   'Beverages, North Indian, South Indian',
#   'Beverages, Continental, Desserts, North Indian',
#   'Beverages, Burger, Cafe, Continental, Pizza',
#   'Bihari',
#   'Andhra, Biryani, Chinese, Hyderabadi, North Indian',
#   'American, Fast Food, Pizza, Seafood',
#   'Asian, BBQ, Chinese, Japanese',
#   'Biryani, Fast Food, Italian, North Indian, Rolls',
#   'Beverages, Fast Food, Ice Cream, Sandwich',
#   'Chinese, Continental, North Indian, Street Food',
#   'Asian, Chinese, Seafood',
#   'Konkan, Mangalorean, Seafood',
#   'Chinese, Fast Food, North Indian, Street Food',
#   'Arabian, Chinese, Kerala, Mughlai, North Indian',
#   'Chinese, Fast Food, North Indian, South Indian, Street Food',
#   'Arabian, BBQ, Chinese, Rolls',
#   'Chinese, Continental, Momos, North Indian',
#   'Continental, Mughlai, North Indian',
#   'Chinese, Fast Food, Italian, North Indian, South Indian',
#   'BBQ, Continental, European, North Indian, Pizza',
#   'North Indian, Seafood, South Indian',
#   'Chinese, Desserts, North Indian, Street Food',
#   'American, Asian, Chinese, Continental, North Indian, South Indian',
#   'Chinese, Thai, Vietnamese',
#   'Beverages, Burger, Desserts, Fast Food, Ice Cream, Pizza, Sandwich',
#   'Lebanese',
#   'American, European',
#   'Beverages, Ice Cream, Juices, Sandwich',
#   'Biryani, Hyderabadi',
#   'Australian, Continental',
#   'Cafe, Continental, Italian, Salad',
#   'Healthy Food, North Indian, Salad',
#   'Fast Food, Mithai, Street Food',
#   'BBQ, Chinese, Continental, Steak, Thai',
#   'Bakery, Desserts, Healthy Food',
#   'Seafood, South Indian',
#   'Biryani, Fast Food, Rolls',
#   'Asian, Thai',
#   'Cafe, Chinese, Italian, Pizza',
#   'Asian, Beverages',
#   'Biryani, Chinese, Continental, Italian, North Indian',
#   'Continental, Mediterranean, Mughlai, North Indian, Salad',
#   'Bakery, Fast Food, Fast Food',
#   'Beverages, Kerala',
#   'Andhra, Chettinad',
#   'Chinese, Fast Food, South Indian',
#   'BBQ, Burger, Lebanese, Turkish',
#   'Biryani, Fast Food, Mughlai, North Indian',
#   'North Indian, Rolls',
#   'Biryani, Continental, North Indian, South Indian',
#   'Burger, Italian, Pizza',
#   'Arabian, Beverages, Fast Food',
#   'Cafe, Continental, European, Italian',
#   'American, European, Healthy Food',
#   'Continental, Finger Food, Pizza',
#   'Burger, Fast Food, Street Food',
#   'Arabian, Continental',
#   'American, Continental, Healthy Food, Mediterranean',
#   'Beverages, Healthy Food, Salad',
#   'Italian, Mediterranean, Mexican',
#   'Biryani, Chinese, Mangalorean, North Indian',
#   'Continental, Pizza',
#   'Continental, Italian, Mexican, North Indian',
#   'Italian, Mediterranean, Spanish',
#   'Burmese, Chinese, Continental, Korean, Malaysian, North Indian, Thai, Vietnamese',
#   'Continental, Italian, Japanese, North Indian',
#   'European, French, North Indian',
#   'Arabian, Chinese, Lebanese, Rolls',
#   'American',
#   'Asian, Japanese, Sushi',
#   'Gujarati, Rajasthani',
#   'Chinese, North Indian, Pizza',
#   'European, Mediterranean, Salad',
#   'Burmese, Chinese, Japanese, Korean, Thai',
#   'Thai',
#   'Bengali, Seafood',
#   'American, Continental, North Indian, South Indian',
#   'Chinese, Continental, European, Thai',
#   'European, Mediterranean, North Indian',
#   'BBQ, Biryani, Continental',
#   'Chinese, Continental, Juices, North Indian, South Indian, Street Food',
#   'European, North Indian, Thai',
#   'Continental, Italian, Pizza',
#   'Continental, European, Italian, North Indian',
#   'Lucknowi, North Indian',
#   'Chinese, Indonesian, Thai',
#   'European, Italian',
#   'Asian, Continental, Italian',
#   'Hyderabadi, Mughlai, North Indian',
#   'Cafe, Chinese, North Indian',
#   'Continental, Fast Food, Finger Food',
#   'Chinese, Continental, Italian',
#   'Asian, Continental, North Indian, South Indian',
#   'Continental, Italian, North Indian, South Indian',
#   'American, Burger, Cafe, Continental',
#   'Bakery, Beverages, Burger, Cafe, Continental',
#   'Burger, Cafe, Continental, Pizza, Steak',
#   'American, Burger, Cafe, Italian',
#   'Burger, Cafe, Continental, Steak',
#   'Beverages, Cafe, Pizza',
#   'Asian, Cafe, Desserts, Healthy Food, Italian, Pizza, Salad',
#   'American, Burger, Cafe, Steak',
#   'American, Cafe, Continental',
#   'American, Cafe, Continental, Desserts',
#   'Bakery, Cafe, Desserts, Italian',
#   'Cafe, Continental, Italian, North Indian, Salad, South Indian',
#   'American, Burger, Cafe, Italian, Steak',
#   'Bakery, Burger, Cafe, Italian, Salad, Sandwich',
#   'Cafe, Desserts, Pizza, Salad',
#   'Cafe, Japanese',
#   'Beverages, Cafe, Continental, Healthy Food, Italian, Salad, Sandwich',
#   'BBQ, Burger, Cafe, Continental, Pizza, Wraps',
#   'Beverages, Burger, Cafe, Continental, Italian',
#   'American, Burger, Cafe, Italian, Pizza',
#   'American, Cafe, Continental, Steak',
#   'Burger, Cafe, Fast Food',
#   'Burger, Cafe, Fast Food, Italian',
#   'Cafe, Coffee, Italian',
#   'Cafe, Lebanese, Mediterranean',
#   'Bakery, Cafe, Continental',
#   'Cafe, Healthy Food, Italian',
#   'Cafe, North Indian, Tea',
#   'Burger, Cafe, Fast Food, Finger Food, Italian, Pizza, Sandwich',
#   'Beverages, Cafe, Fast Food, Juices',
#   'Cafe, Fast Food, North Indian',
#   'Cafe, Chinese',
#   'Cafe, Continental, Salad',
#   'Cafe, Chinese, Continental, Desserts, Ice Cream, North Indian, Pizza',
#   'Cafe, Continental, Japanese, North Indian, Thai',
#   'Cafe, Continental, Desserts, Momos, Salad',
#   'Burger, Cafe',
#   'Cafe, Desserts, Tea',
#   'Biryani, Healthy Food, North Indian',
#   'Arabian, Chinese, Kebab, North Indian',
#   'Burger, Desserts, Fast Food',
#   'African, Portuguese',
#   'Arabian, Chinese, Fast Food, Kebab, Mughlai',
#   'Beverages, Desserts, Fast Food, Ice Cream',
#   'Arabian, Beverages, Chinese, North Indian',
#   'Arabian, Beverages, North Indian',
#   'North Indian, Parsi',
#   'Desserts, European, Italian, Juices, Salad, Steak',
#   'Asian, Indonesian, Thai',
#   'Fast Food, Kebab, North Indian',
#   'American, BBQ, Burger, Continental, Italian, Salad, Steak',
#   'Momos, Nepalese, Tibetan',
#   'Arabian, Biryani, Kebab, Rolls',
#   'Biryani, Chinese, Juices, Kebab, North Indian',
#   'Healthy Food, North Indian, South Indian',
#   'Arabian, Biryani, North Indian',
#   'Asian, BBQ, Chinese, Momos, Thai',
#   'Andhra, Biryani, Chinese, North Indian, Seafood, South Indian',
#   'Bakery, Beverages, Cafe, Greek, Mediterranean',
#   'Healthy Food, Sandwich',
#   'Bengali, Fast Food, Rolls',
#   'Beverages, Fast Food, Juices, Pizza, Rolls',
#   'Chinese, Momos, Nepalese',
#   'Asian, Japanese',
#   'American, Chinese, Finger Food, Momos, North Indian',
#   'Maharashtrian, North Indian, South Indian',
#   'Desserts, Mughlai, North Indian',
#   'American, Arabian, Cafe, Chinese, Italian, North Indian',
#   'Continental, European, Mediterranean',
#   'Goan, Mangalorean, Pizza',
#   'Asian, European, Mediterranean, North Indian, Salad',
#   'Burger, Chinese, Continental, North Indian, Pizza',
#   'Burmese',
#   'Asian, Chinese, Fast Food, Indonesian, Korean, Momos',
#   'American, Continental, Salad, Steak',
#   'American, Cafe, Coffee, Continental, Fast Food',
#   'Fast Food, Mughlai, North Indian, Rolls',
#   'American, Continental, Fast Food, Steak',
#   'Arabian, North Indian, South Indian',
#   'Chinese, Fast Food, South Indian, Street Food',
#   'Continental, South Indian',
#   'Chinese, Kebab, Mughlai, North Indian',
#   'North Eastern',
#   'Arabian, Lebanese, Mediterranean, Rolls',
#   'Chinese, Continental',
#   'Biryani, Fast Food, South Indian',
#   'Beverages, Cafe, Continental, Italian',
#   'Chettinad',
#   'Bar Food, Konkan, Mangalorean, Seafood, South Indian',
#   'Beverages, Burger, Continental, Italian',
#   'American, Italian, Mexican, Steak',
#   'Chinese, Momos, Nepalese, Tibetan',
#   'Arabian, Chinese, Fast Food',
#   'Chinese, European, North Indian',
#   'Desserts, Goan, Konkan, Seafood',
#   'Cafe, Continental, Italian, Mediterranean, Pizza',
#   'Asian',
#   'Arabian, Chinese, Mughlai, North Indian',
#   'Chinese, Mangalorean, North Indian, Seafood, South Indian',
#   'Andhra, Biryani, Seafood',
#   'Chinese, Kerala, North Indian, South Indian',
#   'Mexican',
#   'Continental, Lebanese, Mexican',
#   'Chinese, Mangalorean, Seafood',
#   'Bakery, Beverages, Cafe, Desserts, Spanish',
#   'Chinese, Japanese, Momos, Tibetan',
#   'Chinese, Fast Food, Momos',
#   'Chinese, Pizza, Rolls',
#   'Asian, Indonesian, Japanese, Korean, Malaysian, Singaporean',
#   'Chinese, Continental, Mughlai, North Indian, Steak',
#   'Awadhi, Bengali, North Indian',
#   'BBQ, Continental, Finger Food',
#   'Chinese, Seafood',
#   'Burger, Momos, Pizza',
#   'Japanese',
#   'American, BBQ, Continental, Italian, Salad, Steak',
#   'American, Finger Food',
#   'Chinese, Healthy Food, North Indian',
#   'American, Pizza',
#   'Chinese, Seafood, Thai',
#   'Chinese, Continental, Steak',
#   'European, Fast Food',
#   'American, Continental, Italian, Steak',
#   'Continental, North Indian, Thai',
#   'Mughlai',
#   'American, Burger, Italian',
#   'Asian, Chinese, Continental, North Indian, Thai',
#   'Kerala, Seafood',
#   'Continental, European, Italian, Seafood',
#   'Biryani, Mangalorean, South Indian',
#   'Continental, Fast Food, Pizza',
#   'Biryani, Chettinad, South Indian',
#   'Desserts, Healthy Food, Italian, Kebab, Mediterranean, Pizza, Salad',
#   'Chinese, Continental, Fast Food',
#   'Continental, Steak',
#   'Beverages, Continental, Modern Indian, North Indian, Pizza',
#   'Asian, Momos, Naga, North Eastern, Steak',
#   'Fast Food, Italian',
#   'Biryani, Chinese, Mughlai, North Indian, Seafood',
#   'Beverages, Fast Food, North Indian',
#   'Mughlai, North Indian, Street Food',
#   'Mithai, North Indian',
#   'Chinese, Italian',
#   'Chinese, Kebab, Mughlai',
#   'Biryani, Fast Food, Mughlai',
#   'Beverages, Desserts, South Indian, Street Food',
#   'Bakery, Beverages',
#   'Bakery, Mithai',
#   'Chinese, Japanese, Korean',
#   'American, Continental, Salad',
#   'Asian, Continental, European, North Indian',
#   'American, Chinese, North Indian',
#   'American, BBQ, Continental, Steak',
#   'Biryani, Chinese, Fast Food, Seafood',
#   'Asian, North Indian, Thai',
#   'BBQ, Continental, Salad',
#   'Asian, Japanese, Thai',
#   'Asian, Cantonese, Chinese, Tea',
#   'American, BBQ',
#   'Kerala, Konkan, Mangalorean, Seafood',
#   'Asian, European',
#   'North Indian, Seafood',
#   'Andhra, Biryani, Chettinad, Kerala, Konkan, Mangalorean, South Indian',
#   'Asian, Chinese, Japanese, Korean, Malaysian, Thai, Vietnamese',
#   'European, Italian, Mediterranean, Salad, Spanish',
#   'Asian, Burger, Chinese, Finger Food',
#   'Italian, Mediterranean',
#   'Asian, Italian, Mediterranean',
#   'Continental, French, Italian, Mediterranean',
#   'European, French, Salad',
#   'Continental, Finger Food, North Indian, Pizza',
#   'Asian, Chinese, Indonesian, Momos, Thai',
#   'Burger, Continental, Italian',
#   'Chinese, Desserts, Fast Food, North Indian, Street Food',
#   'Malaysian, Singaporean, Thai',
#   'Chinese, Japanese, Thai',
#   'Asian, European, Grill, North Indian, Salad, Seafood, South Indian',
#   'Finger Food, Mediterranean, North Indian',
#   'Chinese, Mediterranean, North Indian',
#   'Asian, Continental, Finger Food, North Indian',
#   'Arabian, Chinese, North Indian, Rolls',
#   'American, European, North Indian, Tex-Mex',
#   'Spanish',
#   'Asian, Mediterranean, North Indian',
#   'Biryani, Chinese, Mughlai, North Indian, South Indian',
#   'Grill, Mediterranean, Steak',
#   'Chinese, Continental, Italian, North Indian, Seafood, Thai',
#   'American, Asian, Mediterranean',
#   'Beverages, Chinese, Street Food',
#   'Bihari, Fast Food, North Indian',
#   'Beverages, Continental, Desserts, Fast Food',
#   'Maharashtrian, North Indian',
#   'Continental, Finger Food, North Indian',
#   'American, BBQ, Finger Food, Steak',
#   'American, Beverages, Cafe, Italian',
#   'Arabian, Beverages, Biryani, Mughlai, North Indian, Seafood',
#   'Asian, BBQ, Mediterranean, North Indian',
#   'Afghan, Biryani, Mughlai, North Indian',
#   'Continental, Finger Food, Italian, North Indian',
#   'Asian, Continental, European, Mediterranean',
#   'American, Asian, Continental, North Indian, South Indian',
#   'American, Italian, North Indian',
#   'Asian, North Indian, South Indian',
#   'Continental, Italian, Mediterranean, Mexican, North Indian',
#   'Arabian, Chinese, Continental, North Indian',
#   'Bakery, Cafe, Fast Food',
#   'Beverages, Burger, Cafe, Chinese, Fast Food',
#   'American, Burger, Cafe, Continental, Desserts, French, Mexican, Pizza',
#   'Cafe, Continental, Italian, North Indian',
#   'Beverages, Cafe, Tea',
#   'Beverages, Cafe, Sandwich',
#   'Cafe, Chinese, Continental',
#   'Bakery, Cafe, Desserts, Italian, Pizza',
#   'Rolls, Sandwich',
#   'Beverages, Chinese, Desserts, Fast Food, North Indian',
#   'Beverages, Fast Food, Healthy Food, North Indian, South Indian',
#   'Chinese, Continental, Fast Food, Momos, Rolls',
#   'Beverages, Burger, Fast Food, Pizza',
#   'Arabian, Biryani, Chinese, Kerala, North Indian',
#   'Arabian, Beverages, Chinese, North Indian, Salad',
#   'Beverages, Desserts, Sandwich, Street Food',
#   'Chinese, Mithai, North Indian, South Indian, Street Food',
#   'Arabian, Biryani, Chinese, Fast Food, North Indian',
#   'Arabian, Biryani, Chinese, Mughlai',
#   'Beverages, Chinese, Momos, Thai',
#   'Chettinad, Chinese, South Indian',
#   'Andhra, BBQ, Chinese, North Indian, Seafood',
#   'Kerala, North Indian, Seafood, South Indian',
#   'Beverages, Biryani, South Indian',
#   'Beverages, Desserts, Mithai, North Indian, Street Food',
#   'Bengali, Chinese, North Indian, Oriya',
#   'Bihari, North Indian, South Indian',
#   'Chinese, Mithai, North Indian',
#   'BBQ, Continental, North Indian, Steak',
#   'Gujarati, North Indian',
#   'Arabian, Beverages, Biryani, Chinese, Kerala, North Indian, South Indian',
#   'Arabian, BBQ, Lebanese, Mughlai, North Indian',
#   'Bengali, Biryani, North Indian, Oriya, Seafood',
#   'Chinese, Kerala, Seafood',
#   'Arabian, Biryani, Chinese, Hyderabadi, North Indian, South Indian',
#   'American, Asian, Italian, Japanese, North Indian, Steak',
#   'Korean, Sushi',
#   'Mughlai, North Indian, South Indian',
#   'American, Cafe, Continental, Italian, Salad, Steak',
#   'Bihari, North Indian, Rajasthani',
#   'Juices, North Indian',
#   'Arabian, Desserts, Fast Food, Healthy Food, Salad, Turkish',
#   'Cafe, Desserts, Fast Food, Italian',
#   'Andhra, Hyderabadi, South Indian',
#   'BBQ, Burger, Fast Food, North Indian',
#   'Chinese, Japanese, Sushi, Thai',
#   'Andhra, Kerala, South Indian',
#   'Beverages, Burger, Fast Food, Finger Food, Sandwich, Street Food',
#   'Arabian, Beverages, Biryani, Desserts, Salad',
#   'Beverages, Bubble Tea, Tea',
#   'Oriya',
#   'American, Burger, Continental, Finger Food, Pizza',
#   'Biryani, Kerala',
#   'Beverages, Desserts, Sandwich',
#   'Biryani, Lucknowi',
#   'Andhra, Beverages, Chinese',
#   'Biryani, Hyderabadi, North Indian, Seafood',
#   'Andhra, Beverages, Biryani, Kebab',
#   'North Indian, Sandwich',
#   'Burger, Chinese, Fast Food, Hot dogs, Sandwich',
#   'Andhra, Biryani, Chinese, North Indian, Seafood',
#   'Biryani, Kebab, North Indian, Rolls',
#   'Asian, Continental, Italian, North Indian',
#   'Fast Food, North Indian, Pizza',
#   'Biryani, Chinese, Juices, North Indian',
#   'Burger, Chinese, North Indian, Sandwich',
#   'Fast Food, Ice Cream, Juices',
#   'Andhra, Biryani, Mughlai, North Indian',
#   'Chinese, Mughlai, North Indian, Seafood',
#   'Cafe, Kashmiri',
#   'Continental, Mediterranean, North Indian',
#   'Chinese, Continental, Italian, Momos, North Indian',
#   'Kerala, Seafood, South Indian',
#   'Chinese, Kerala',
#   'Chinese, Momos, Seafood',
#   'Tibetan',
#   'Fast Food, Gujarati',
#   'Biryani, Chinese, Continental, North Indian, Thai',
#   'Beverages, Fast Food, North Indian, Street Food',
#   'Andhra, Fast Food, South Indian',
#   'Kebab, North Indian',
#   'Beverages, Mughlai, North Indian, South Indian',
#   'Bengali, Biryani, Chinese, North Indian',
#   'Fast Food, Sandwich, South Indian',
#   'Gujarati, North Indian, Rajasthani',
#   'Biryani, Charcoal Chicken',
#   'Burger, Continental, Italian, Mediterranean',
#   'Cafe, Italian, North Indian, Pizza',
#   'Beverages, Biryani, Chinese, North Indian, South Indian',
#   'Asian, Continental, North Indian, Pizza',
#   'Continental, Mexican, North Indian',
#   'Bakery, French, Pizza',
#   'Asian, BBQ, Chinese, Continental, European',
#   'American, North Indian, Salad',
#   'American, Asian, Finger Food, Italian',
#   'Asian, Chinese, North Indian, Thai',
#   'BBQ, Burger, Continental',
#   'Arabian, Chinese, Fast Food, North Indian',
#   'Asian, Bakery, Chinese, Continental, European, Italian, Japanese, North Indian',
#   'Asian, European, Modern Indian',
#   'Chinese, Continental, North Indian, Salad, Thai',
#   'American, Asian, Continental, Desserts, North Indian',
#   'Mughlai, North Indian, Salad',
#   'Asian, Chinese, Momos, Thai',
#   'Andhra, Chettinad, Kerala',
#   'Gujarati, North Indian, Rajasthani, South Indian',
#   'Arabian, Chinese, North Indian, South Indian',
#   'Chinese, Continental, North Indian, South Indian, Thai',
#   'Cafe, Lebanese',
#   'Beverages, Cafe, Healthy Food, Salad',
#   'Cafe, Fast Food, Italian',
#   'Cafe, Continental, European, Juices',
#   'American, Beverages, Burger, Cafe, Sandwich',
#   'Cafe, Continental, Fast Food, Italian, Steak',
#   'Cafe, Salad',
#   'Cafe, Continental, European',
#   'Cafe, Continental, Desserts',
#   'Beverages, Cafe, Continental, Desserts, Healthy Food, Pizza, Sandwich',
#   'Beverages, Cafe, Continental, Mediterranean',
#   'Beverages, Cafe, Desserts, Healthy Food, Salad',
#   'Cafe, Continental, Mexican',
#   'Cafe, Continental, Salad, Steak',
#   'Cafe, Street Food, Tea',
#   'Beverages, Cafe, Healthy Food, Juices',
#   'Burger, Cafe, Desserts, Fast Food',
#   'Beverages, Chinese, Mithai, North Indian, Street Food',
#   'Asian, Chinese, Malaysian, Momos, Thai',
#   'Desserts, Mithai, North Indian, Rajasthani, Street Food',
#   'Chinese, Ice Cream, Juices, North Indian, South Indian',
#   'Beverages, Street Food, Tea',
#   'Biryani, Chinese, Juices, Kerala, North Indian, Seafood, South Indian',
#   'Burger, Cafe, Continental, Healthy Food, Italian, Salad',
#   'European, Italian, Mediterranean, Sandwich',
#   'Beverages, Bubble Tea, Desserts',
#   'Chettinad, South Indian',
#   'Beverages, Desserts, Fast Food, South Indian, Street Food',
#   'Healthy Food, Italian, North Indian, Pizza, South Indian',
#   'Cafe, North Indian, Pizza, Salad, Sandwich',
#   'Chinese, Continental, Momos, Tibetan',
#   'Fast Food, Momos, North Indian, Rolls',
#   'Biryani, Chinese, Continental, Kerala, North Indian, South Indian',
#   'BBQ, Biryani, Italian',
#   'Arabian, Burger, Rolls, Sandwich',
#   'Kebab, Rolls',
#   'American, Chinese, Fast Food',
#   'Chinese, Kerala, North Indian, Seafood',
#   ...],
#  'listed_in_type': ['Buffet',
#   'Cafes',
#   'Delivery',
#   'Desserts',
#   'Dine-out',
#   'Drinks & nightlife',
#   'Pubs and bars'],
#  'listed_in_city': ['Banashankari',
#   'Bannerghatta Road',
#   'Basavanagudi',
#   'Bellandur',
#   'Brigade Road',
#   'Brookefield',
#   'BTM',
#   'Church Street',
#   'Electronic City',
#   'Frazer Town',
#   'HSR',
#   'Indiranagar',
#   'Jayanagar',
#   'JP Nagar',
#   'Kalyan Nagar',
#   'Kammanahalli',
#   'Koramangala 4th Block',
#   'Koramangala 5th Block',
#   'Koramangala 6th Block',
#   'Koramangala 7th Block',
#   'Lavelle Road',
#   'Malleshwaram',
#   'Marathahalli',
#   'MG Road',
#   'New BEL Road',
#   'Old Airport Road',
#   'Rajajinagar',
#   'Residency Road',
#   'Sarjapur Road',
#   'Whitefield']}
